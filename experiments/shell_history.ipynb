# %%
from PIL import Image

import pytesseract
import glob, os
from pprint import pprint
import requests

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# Read my zsh history into an array
with open(os.getenv("HOME") + "/.zsh_history") as f:
    history = f.readlines()

# Remove the timestamp
history = [line.split(";")[-1].strip() for line in history]
# history = [line.split(";")[1] for line in history]

# Remove duplicates
history = list(set(history))


# Remove the newline character
display(history[0:10])
# Out:
# ['',
#  'asdf install plugin ruby',
#  'gnb slower-video',
#  'cd test-failed-collections',
#  'echo $FASTLANE_USER',
#  'yarn up:prod -y',
#  'rm test/types.d.ts',
#  'brew install weaveworks/tap/eksctl',
#  'git diff src/ws',
#  'conda init zsh']

# %%
# Find similar commands using the Hugging Face Inference API
token = os.environ['HUGGING_FACE_TOKEN']

API_URL = "https://api-inference.huggingface.co/models/sentence-transformers/all-MiniLM-L6-v2"
headers = {"Authorization": f"Bearer {token}"}

def query(payload):
	response = requests.post(API_URL, headers=headers, json=payload)
	return response.json()

def best_matches_remote(command):
    output = query({
      "inputs": {
        "source_sentence": command,
        "sentences": history
      },
    })
    if ('error' in output):
      raise Exception(output['error'])

    scored_entries = list(zip(history, output))
    top_matches = sorted(scored_entries, key=lambda x: x[1], reverse=True)[:10]

    print(f"\nTop matches for command `{command}`:")
    for command, probability in top_matches:
      print(f"\t{command.ljust(30)}: {probability:.2f}")

    return sorted(scored_entries, key=lambda x: x[1], reverse=True)

best_matches_remote("test collections resolver")
# Out:
# Top matches for command `test collections resolver`:
# 	open test/data/test-failed-collections: 0.56
# 	./bin/ctest --watchAll --testPathPattern map.resolver: 0.55
# 	./bin/ctest --watchAll --testPathPattern map.resolver.e2e: 0.52
# 	./bin/ctest --watchAll --testPathPattern my-blocks.resolver: 0.51
# 	./bin/ctest --watchAll --testPathPattern map-resolver.e2e: 0.51
# 	cd test-failed-collections    : 0.50
# 	./bin/ctest --watchAll --testPathPattern /collection.entity: 0.50
# 	./bin/ctest --watchAll --testPathPattern upgrade-block.resolver: 0.49
# 	git checkout -b test-failing-collections: 0.41
# 	./bin/cyarn command test-failed-collections: 0.40
# [('open test/data/test-failed-collections', 0.557887852191925),
#  ('./bin/ctest --watchAll --testPathPattern map.resolver', 0.5521204471588135),
#  ('./bin/ctest --watchAll --testPathPattern map.resolver.e2e',
#   0.5180151462554932),
#  ('./bin/ctest --watchAll --testPathPattern my-blocks.resolver',
#   0.5114028453826904),
#  ('./bin/ctest --watchAll --testPathPattern map-resolver.e2e',
#   0.5093898177146912),
#  ('cd test-failed-collections', 0.5004050731658936),
#  ('./bin/ctest --watchAll --testPathPattern /collection.entity',
#   0.49936869740486145),
#  ('./bin/ctest --watchAll --testPathPattern upgrade-block.resolver',
#   0.4852907657623291),
#  ('git checkout -b test-failing-collections', 0.40675827860832214),
#  ('./bin/cyarn command test-failed-collections', 0.3983614444732666),
#  ('find src/ | entr -s "./bin/cyarn command test-failed-collections"',
#   0.3666009306907654),
#  ('rm test/types.d.ts', 0.36168211698532104),
#  ('cd docquery-tests', 0.34414801001548767),
#  ('git checkout src/map/map.resolver.ts', 0.34224680066108704),
#  ('rm ../world-server/src/collections/collection.utils.ts',
#   0.33965668082237244),
#  ('git diff ../world-server/src/map/map.resolver.ts', 0.33250388503074646),
#  ('git add ../world-server/src/collections/collection.utils.ts',
#   0.3289058208465576),
#  ('ls find src/ | entr -s "./bin/cyarn command test-failed-collections"',
#   0.32829761505126953),
#  ('git checkout ../world-server/src/collections/collection.utils.ts',
#   0.32570672035217285),
#  ('git checkout ../world-server/src/map/map.resolver.ts', 0.3242342472076416),
#  ('smartctl --scan', 0.3211927115917206),
#  ('ls src/* | entr -s "./bin/cyarn command test-failed-collections"',
#   0.3181556165218353),
#  ('mkdir docquery-tests', 0.316173255443573),
#  ('gnb reprocess-collections', 0.3129213750362396),
#  ('gnb more-server-tests', 0.3092787563800812),
#  ('cd test/data', 0.3075154721736908),
#  ('git show collection-logging', 0.30709144473075867),
#  ('./bin/ctest --watchAll --testPathPattern block.service',
#   0.30418452620506287),
#  ('code ~/Desktop/reprocess-collections.ipynb', 0.30178141593933105),
#  ('./bin/ctest --watchAll --testPathPattern block-upgrade.entity',
#   0.3009779751300812),
#  ('git checkout ../world-server/src/users/users.resolver.ts',
#   0.2994827926158905),
#  ('./bin/ctest --watchAll --testPathPattern my-blocks', 0.2920728623867035),
#  ('git checkout pending-collections', 0.28045928478240967),
#  ('git revert src/map/map.resolver.ts', 0.27838099002838135),
#  ('git commit -m "Add tests to `myBlocks` endpoint"', 0.2761561870574951),
#  ('gnb test-server', 0.2713734209537506),
#  ('./bin/ctest --watchAll --testPathPattern user.service',
#   0.27022773027420044),
#  ('git checkout -b pending-collections', 0.26360976696014404),
#  ('git branch -D collection-logging', 0.2629926800727844),
#  ('git reset ../world-server/src/collections/collection.utils.ts',
#   0.2627776563167572),
#  ('find ../node_modules/expo/android/build.gradle | entr -s "./bin/cyarn command test-failed-collections"',
#   0.257732093334198),
#  ('./bin/ctest --watchAll --testPathPattern block-upgrade',
#   0.25761276483535767),
#  ('gnb tests', 0.2537584602832794),
#  ('gitk --all --first-parent --remotes --reflog --author-date-order -- /Users/kylecorbitt/proj/reality-platforms/miner/src/utils/collections.ts',
#   0.2530384063720703),
#  ('git checkout test/generated/graphql.ts', 0.25053513050079346),
#  ('git log --all --first-parent --remotes --reflog --author-date-order -- /Users/kylecorbitt/proj/reality-platforms/miner/src/utils/collections.ts',
#   0.25000301003456116),
#  ('git commit -am "reprocess unprocessed collections"', 0.24386562407016754),
#  ('gnb collection-logging', 0.23916706442832947),
#  ('ifconfig | grep 192', 0.2375529408454895),
#  ('git commit -m "no need to load collections on the map page anymore"',
#   0.2339700609445572),
#  ('git checkout src/collections/process-collection/reprocess-collection.job.ts',
#   0.22251518070697784),
#  ('git commit -m "simplify e2e tests"', 0.22115716338157654),
#  ('git commit -am "Don\'t show capture quality before first collection"',
#   0.21999384462833405),
#  ('gnb test-panos', 0.21713344752788544),
#  ('rm -r ceres-solver*', 0.21548038721084595),
#  ('rm -rf docquery', 0.20811296999454498),
#  ('smartctl', 0.20638687908649445),
#  ('cd experiments', 0.19961558282375336),
#  ('git merge night-collections', 0.19777625799179077),
#  ('cat ~/.ssh/known_hosts', 0.1965683102607727),
#  ('smartctl -a disk0`', 0.19219529628753662),
#  ('dig docs.realityplatforms.org', 0.1921135038137436),
#  ('smartctl -a disk0', 0.19191515445709229),
#  ('ifconfig | grep 10', 0.19089572131633759),
#  ('smartctl IOService', 0.1879846453666687),
#  ('git checkout test-panos', 0.18165592849254608),
#  ('./bin/ctest', 0.17941704392433167),
#  ('./bin/ctest --watchAll', 0.17760920524597168),
#  ('smartctl -h', 0.1730249673128128),
#  ('git checkout night-collections', 0.17114034295082092),
#  ('config config --local status.showUntrackedFiles no\\', 0.16523325443267822),
#  ('./bin/cyarn typecheck', 0.16298235952854156),
#  ('conda activate ldm', 0.1626870185136795),
#  ('cat package.json', 0.16266818344593048),
#  ('protoc --version', 0.1612161546945572),
#  ('rsync -r ml:~/ml-experiments ml-experiments', 0.1609744131565094),
#  ('open test-out.mp4', 0.15868403017520905),
#  ('yarn ios --scheme "RM Local Debug"', 0.15773046016693115),
#  ('cat ios/RealityMiner.xcworkspace/xcshareddata/swiftpm/Package.resolved',
#   0.1552390158176422),
#  ('git diff db/migrations/.snapshot-worldserver.json', 0.15498806536197662),
#  ('yarn check-dependencies', 0.15453331172466278),
#  ('psql -U worldserver -h $NEW_DB_DOMAIN -d template1 --set ON_ERROR_STOP=on -f /tmp/prod_dump_latest.sql\\',
#   0.15408451855182648),
#  ('git checkout -b night-collections', 0.15388000011444092),
#  ('cd ../ml-experiments', 0.1536465585231781),
#  ('ifconfig', 0.1531704217195511),
#  ('rsync ml:~/ml-experiments ml-experiments', 0.15198276937007904),
#  ('psql -U worldserver -h $NEW_DB_DOMAIN -d template1 --set ON_ERROR_STOP=on -f /tmp/db_dump_stage2.sql\\',
#   0.15144895017147064),
#  ('asdf reshim', 0.15140500664710999),
#  ('git diff src/database.ts', 0.15099184215068817),
#  ('cat Setup\\ notes.md', 0.1499200016260147),
#  ('psql -U worldserver -h $NEW_DB_DOMAIN -d template1 --set ON_ERROR_STOP=on -f /tmp/prod_dump.sql\\',
#   0.14918597042560577),
#  ('git diff src/index.ts', 0.14909957349300385),
#  ('rm -r ml-experiments', 0.14906691014766693),
#  ('cat .tool-versions', 0.14876751601696014),
#  ('psql -U worldserver -h $NEW_DB_DOMAIN -d template1 --set ON_ERROR_STOP=on -f /tmp/db_dump_stage.sql\\',
#   0.148483008146286),
#  ('brew install smartctl', 0.14602093398571014),
#  ('rm -rf trial_remote2', 0.1457759290933609),
#  ('code /Users/kylecorbitt/.ssh/known_hosts', 0.14570318162441254),
#  ('git diff world-server/db/migrations/.snapshot-worldserver.json',
#   0.14498823881149292),
#  ('mv .env .env.local', 0.14445364475250244),
#  ('npx @rnx-kit/dep-check --set-version', 0.1443203240633011),
#  ('cat ~/.tool-versions', 0.14390401542186737),
#  ('yarn add --dev @types/sequential-uuid', 0.14337404072284698),
#  ('mv test-out.mp4 apollo-rock.mp4', 0.14239929616451263),
#  ('yarn add dataloader', 0.14230473339557648),
#  ('mv trial_remote2/* .', 0.1404915302991867),
#  ('which conda', 0.14022725820541382),
#  ('git fetch', 0.14018288254737854),
#  ('mkdir ~/proj/ml-experiments', 0.13960544764995575),
#  ('git diff | grep console', 0.13924071192741394),
#  ('git diff package.json', 0.138615220785141),
#  ('psql -U worldserver -h $NEW_DB_DOMAIN', 0.13773022592067719),
#  ('which javac', 0.13715168833732605),
#  ('yarn typecheck', 0.13688184320926666),
#  ('git diff ../world-server/src/commands/command.module.ts',
#   0.13610395789146423),
#  ('rm ../website/tsconfig.tsbuildinfo', 0.13565979897975922),
#  ('yarn psql:stage', 0.1354944258928299),
#  ('config diff', 0.13545966148376465),
#  ('code .gitignore', 0.13505378365516663),
#  ('rclone mount ml:ml-experiments ml-experiments-local', 0.13444599509239197),
#  ('./gradlew installLocalDebug --refresh-dependencies --stacktrace',
#   0.13391301035881042),
#  ('cat ~/.gitignore_global', 0.1338479369878769),
#  ('code ../.github/workflows/miner-checks.yml', 0.13342931866645813),
#  ('asdf list all ruby', 0.1333903968334198),
#  ('cd ../infra', 0.13271328806877136),
#  ('$(brew --prefix anaconda)', 0.13248088955879211),
#  ('find src', 0.13191531598567963),
#  ('code .tool-versions', 0.1308695673942566),
#  ('z ifnra', 0.13077543675899506),
#  ('rclone ml:~/ml-experiments/results ./ml-experiments', 0.1304260492324829),
#  ('yarn add expo-file-system expo-application expo-device expo-localization',
#   0.130083829164505),
#  ('./bin/cyarn lint', 0.12995144724845886),
#  ('mv trial_remote2/* trial_remote2', 0.1299053281545639),
#  ('poetry run docquery scan "what am I paying in" data/sw2.png --checkpoint \'naver-clova-ix/donut-base-finetuned-docvqa\'',
#   0.12933416664600372),
#  ('rm experiments/ml-machine', 0.12915366888046265),
#  ('yarn get-nexus-appt', 0.12906301021575928),
#  ('config status', 0.12896883487701416),
#  ('cd docquery', 0.12876039743423462),
#  ('yar', 0.1286134421825409),
#  ('git checkout db/migrations/.snapshot-worldserver.json',
#   0.12780989706516266),
#  ('conda update -y -n base -c defaults conda', 0.12780530750751495),
#  ('yarn refresh:stage', 0.12774375081062317),
#  ('git show 63e28fa765c4fa23a1212c629222316586e09204', 0.12712909281253815),
#  ('yarn fix-dependencies', 0.1270069032907486),
#  ('rclone sync -i ml:ml-experiments ml-experiments', 0.12695716321468353),
#  ('gnb ftue-bugs', 0.12670591473579407),
#  ('./bin/cyarn command backfill-is-night-collection', 0.12577137351036072),
#  ('ls ios/RealityMiner.xcworkspace/xcshareddata/swiftpm/Package.resolved',
#   0.12569689750671387),
#  ('code ../miner/env/stage', 0.12563703954219818),
#  ('z iniat', 0.12503285706043243),
#  ('git commit -am "Set CNAME for docs.realityplatforms.org"',
#   0.12474988400936127),
#  ('meld /tmp/db_dump_stage.sql /tmp/db_dump_stage2.sql', 0.12457415461540222),
#  ('rclone mount ml:ml-experiments ~/proj/ml-experiments', 0.12376753985881805),
#  ('git diff ../miner/package.json', 0.12359701097011566),
#  ('./gradlew installLocalDebug --refresh-dependencies', 0.12290803343057632),
#  ('git diff src/users/user.service.spec.ts', 0.12265896052122116),
#  ('poetry run docquery', 0.12201540917158127),
#  ('code ~/.tool-versions', 0.12196887284517288),
#  ('z infra', 0.12125025689601898),
#  ('git checkout -b metaverse-sample', 0.11965078115463257),
#  ('rclone sync ml:ml-experiments ml-experiments', 0.11956104636192322),
#  ('cd docs', 0.11939069628715515),
#  ('yarn tsc', 0.11872342228889465),
#  ('cat ~/.gradle/gradle.properties', 0.11826340854167938),
#  ('./gradlew list', 0.11797452718019485),
#  ('cat .env.production', 0.11771097779273987),
#  ('cd ml-experiments', 0.11691883206367493),
#  ('rm Setup\\ notes.md', 0.11650809645652771),
#  ('git diff src/generated/graphql.ts', 0.1162537932395935),
#  ('yarn remove sequential-uuid', 0.11602124571800232),
#  ('./gradlew clean --stacktrace', 0.11570080369710922),
#  ('yarn add @rnx-kit/dep-check --dev', 0.11558276414871216),
#  ('npm version patch', 0.11510176956653595),
#  ('open /tmp/db_dump_stage.sql', 0.11509689688682556),
#  ('conda init zsh', 0.11491762101650238),
#  ('pip install docquery', 0.11471535265445709),
#  ('z server', 0.11422500014305115),
#  ('git commit -m "correct provider"', 0.11418211460113525),
#  ('conda', 0.1139945313334465),
#  ('cd data', 0.11361447721719742),
#  ('yarn sup:stage', 0.11346624791622162),
#  ('rm docs', 0.11330710351467133),
#  ('git checkout fix-block-index', 0.11312494426965714),
#  ('git diff src/ws2/index.ts', 0.11274456977844238),
#  ('ln -s /opt/homebrew/anaconda3/bin/conda /usr/local/bin/conda',
#   0.112689308822155),
#  ('ln -s /usr/local/bin/conda /opt/homebrew/anaconda3/bin/conda',
#   0.11264968663454056),
#  ('gnb fix-block-index', 0.1125430315732956),
#  ('javac --version', 0.1124425008893013),
#  ('git rebase more-ftue', 0.11240240931510925),
#  ('code /tmp/stack.json', 0.11238411068916321),
#  ('git diff | grep Quality', 0.11236920207738876),
#  ('cat /tmp/prod_dump.sql', 0.11225366592407227),
#  ('git diff src/ws2/database.ts', 0.11081286519765854),
#  ('rm -r experiments/ml-machine', 0.1100839376449585),
#  ('config pull --rebase', 0.10994555801153183),
#  ('git add db/migrations/.snapshot-worldserver.json', 0.10898741334676743),
#  ('wormhole help', 0.10891279578208923),
#  ('git diff src/ws2/cluster.ts', 0.10882505774497986),
#  ('cd miner', 0.10854741930961609),
#  ('adb reverse tcp:8081 tcp:8081 && ./gradlew app:assembleLocalDebug',
#   0.10833780467510223),
#  ('code AwesomeProject', 0.10806331038475037),
#  ('rm -rf /opt/homebrew/anaconda3/envs/ldm', 0.10773708671331406),
#  ('git commit -am "service serves over https, but still not registering instances"',
#   0.10749482363462448),
#  ('yarn codegen --watch', 0.10742219537496567),
#  ('cd world-server', 0.10734238475561142),
#  ('which rustc', 0.1064959168434143),
#  ('git diff src', 0.10633686929941177),
#  ('git show 07b956cb87467fc84aa3d9fd1354c56c61ceb7ad', 0.10592394322156906),
#  ('cat temp/Block.js.json', 0.1059083566069603),
#  ('yarn add @rnx-kit/dep-check --dev\\', 0.10577955842018127),
#  ('cmake', 0.10516653954982758),
#  ('cat dev', 0.10513707250356674),
#  ('wormhole receive 9-travesty-tracker', 0.10499095171689987),
#  ('poetry run docquery scan "how many fliers" data/sw2.png',
#   0.10473854094743729),
#  ('which cmake', 0.1039888933300972),
#  ('git diff src/app.module.ts', 0.10393865406513214),
#  ('git commit -am "show FTUE miner"', 0.10389415174722672),
#  ('rclone mount ml:ml-experiments ml-experiments', 0.10379081219434738),
#  ('code --wait package.json', 0.10349074006080627),
#  ('git stash list -p | grep tsx', 0.10327509790658951),
#  ('git checkout --mine package.json', 0.10315697640180588),
#  ('yarn add sequential-uuid', 0.10293148458003998),
#  ('cd dev', 0.10286851227283478),
#  ('git commit -m "Check the ToS whenever"', 0.10286295413970947),
#  ('yarn refresh:prod -y', 0.1028023213148117),
#  ('poetry run docquery scan "am I paying in points or dollars" data/sw2.png --checkpoint \'naver-clova-ix/donut-base-finetuned-docvqa\'',
#   0.10267486423254013),
#  ('NEW_DB=`pulumi stack output newDbUrl --show-secrets --stack reality-platforms/prod`\\',
#   0.10259685665369034),
#  ('OLD_DB=`pulumi stack output oldDbUrl --show-secrets --stack reality-platforms/prod`\\',
#   0.10253891348838806),
#  ('./bin/cyarn codegen --watch', 0.10179949551820755),
#  ('NEW_DB=`pulumi stack output newDbUrl --show-secrets --stack reality-platforms/stage`\\',
#   0.10166606307029724),
#  ('cd src', 0.1016470342874527),
#  ('OLD_DB=`pulumi stack output oldDbUrl --show-secrets --stack reality-platforms/stage`\\',
#   0.10154151916503906),
#  ('git diff ../miner/ios/RealityMiner.xcodeproj/project.pbxproj',
#   0.10151692479848862),
#  ('git commit -am "correct CNAME domain"', 0.10140491276979446),
#  ('open /tmp/stack.json', 0.10137855261564255),
#  ('gnb ftue-triggers', 0.10075567662715912),
#  ('git show 73f4c0a11b3e486aebbe0d4f4e3adb53cae0cd92', 0.1006251722574234),
#  ('git checkout deploy-scanner', 0.10056081414222717),
#  ('pulumi stack output oldDbUrl --stack reality-platforms/stage',
#   0.10052020847797394),
#  ('pulumi stack output analyticsDbUrl --show-secrets --stack reality-platforms.prod',
#   0.10036294162273407),
#  ('mv ml-experiments tmp', 0.10020764172077179),
#  ('git lgo', 0.09991229325532913),
#  ('poetry run docquery scan "what am I paying in" data/sw2.png',
#   0.099665068089962),
#  ('node -a', 0.09966131299734116),
#  ('git fetch --prune', 0.09949120879173279),
#  ('git grep ipynb', 0.09948183596134186),
#  ('yarn add resumed jsonresume-theme-even', 0.0987415611743927),
#  ('find ../node_modules/expo/android/build.gradl', 0.09872622042894363),
#  ('mkdir ml-experiments', 0.09844394028186798),
#  ('rm -rf ~/.gradle/caches', 0.09820868074893951),
#  ('yarn lint', 0.09798207879066467),
#  ('git reflog', 0.09787348657846451),
#  ('yarn refresh --stack=reality-platforms/stage', 0.09761679917573929),
#  ('cat ~/.local/bin', 0.09760893881320953),
#  ('pulumi stack output oldDbUrl --show-secrets --stack reality-platforms/stage',
#   0.09750556200742722),
#  ('cat .gitignore', 0.09737900644540787),
#  ('cat .nvmrc', 0.09717769920825958),
#  ('git commit -a "service serves over https, but still not registering instances"',
#   0.09711837023496628),
#  ('cd nerf', 0.09686223417520523),
#  ('git checkout reality-scanner', 0.09681057929992676),
#  ('node -e \'require("fs").writeFileSync("/Users/kylecorbitt/Library/Application Support/vscode-sqltools/.node-runtime", process.execPath)\' && exit 0',
#   0.09679652005434036),
#  ('git diff src/blocks/block-upgrade.entity.ts', 0.09638836979866028),
#  ('git commit -am "fix lint warning"', 0.09631714969873428),
#  ('git fetch uragirii', 0.0962367057800293),
#  ('z exper', 0.09619482606649399),
#  ('mkdir docquery', 0.09567473828792572),
#  ('config diff ../../../.zshrc', 0.09562847763299942),
#  ('git rebase -i origin/main', 0.09536558389663696),
#  ('yarn add @ntegral/nestjs-sentry', 0.09523525834083557),
#  ('gnb cname', 0.09511369466781616),
#  ('yarn start --reset-cache', 0.09503667801618576),
#  ('cd videos', 0.09500598907470703),
#  ('git checkout ftue-order', 0.09465520083904266),
#  ('git checkout ../miner/env/stage', 0.0946464017033577),
#  ('rm package.json', 0.09456875920295715),
#  ('wormhole', 0.09449313580989838),
#  ('git reflog --no-abbrev', 0.0943419337272644),
#  ('git commit -am "Use higher quality NeRF video"', 0.09424905478954315),
#  ('rustc', 0.0941786840558052),
#  ('/opt/homebrew/anaconda3/bin/conda install zsh', 0.09368454664945602),
#  ('git checkout ../miner/ios/RealityMiner.xcodeproj/project.pbxproj',
#   0.09360247850418091),
#  ('ls docs', 0.09351756423711777),
#  ('poetry run docquery scan "how many fliers" data/southwest.png',
#   0.09318587929010391),
#  ('git add src/index.ts', 0.09302323311567307),
#  ('git checkout src/generated/graphql.ts', 0.09301786869764328),
#  ('git diff src/ws.ts', 0.09265956282615662),
#  ('code .env.local', 0.09264548122882843),
#  ('sudo ln -s /opt/homebrew/anaconda3/bin/conda /usr/local/bin/conda',
#   0.09260395914316177),
#  ('./bin/start-dev --build --renew-anon-volumes\\', 0.09257388859987259),
#  ('yarn add expo-modules-core', 0.09255364537239075),
#  ("NEW_DB_DOMAIN=`echo $NEW_DB | sed 's/^.*\\@\\([^:]*\\):.*$/\\1/'`\\",
#   0.0925338938832283),
#  ('cd ../world-server', 0.09242911636829376),
#  ('rm -rf temp', 0.09224183857440948),
#  ('z minger', 0.09216213971376419),
#  ('gnb fix-tsc', 0.09196346253156662),
#  ('yarn add @sentry/node', 0.091855987906456),
#  ('rm ../infra/src/cluster-roles.ts ../infra/src/roles.ts ../website/.env',
#   0.09181948006153107),
#  ('pulumi stack output analyticsDbUrl --show-secrets --stack reality-platforms/prod',
#   0.09119072556495667),
#  ('git diff src/', 0.09114065021276474),
#  ('config checkout .zshrc', 0.09077255427837372),
#  ('config commit -m "rclone conf"', 0.09046882390975952),
#  ('mv tmp/ml-experiments/ml-experiments .', 0.0901683121919632),
#  ('echo $NEW_DB_DOMAIN', 0.09014646708965302),
#  ('yarn add @types/suncalc', 0.08977358043193817),
#  ('psql postgres://worldserver:ZpPsW4dDaORIzTgPjJOhRwwfztOLxNrV@ws-stage.cluster-c5domkzijk75.us-west-2.rds.amazonaws.com:5432/worldserver',
#   0.08961807191371918),
#  ('yarn rnx-dep-check --init app\\', 0.08929763734340668),
#  ('yarn dev', 0.08922770619392395),
#  ('z miner', 0.08921656012535095),
#  ('cd proj', 0.08886652439832687),
#  ('cd /usr/bin', 0.08879774063825607),
#  ('cat env/local', 0.08857874572277069),
#  ('z proj', 0.08802511543035507),
#  ('git rebase -i main', 0.08791512250900269),
#  ('poetry run docquery scan "what fields haven\'t been filled in yet" data/southwest.png',
#   0.0874820426106453),
#  ('mv ml-experiments/ tmp', 0.08746957033872604),
#  ('git add src/database.ts', 0.08736399561166763),
#  ('cat install_colmap.sh | pbcopy', 0.08723164349794388),
#  ('yarn lint --fix', 0.08711233735084534),
#  ('git branch -D redeploy redeploy-count fix-block-index fix-tsc',
#   0.08706140518188477),
#  ('z expo', 0.087043896317482),
#  ('git commit -am "update the deployed count"', 0.08703230321407318),
#  ('adb reverse tcp:8081 tcp:8081 && ./android/gradlew app:assembleLocalDebug',
#   0.08701028674840927),
#  ('cat ~/.ssh/id_rsa.pub', 0.08669310063123703),
#  ('git checkout -b deploy-scanner', 0.08647860586643219),
#  ('dig apply.watermarkhomeloans.com', 0.08645571768283844),
#  ('git checkout staging-k8s -- package.json', 0.08642511814832687),
#  ('mv 0.68.2..0.70.1.diff upgrade.diff', 0.08625278621912003),
#  ('git checkout package.json', 0.08615047484636307),
#  ('cat .env', 0.08561272919178009),
#  ('poetry run docquery scan "what is the departure airport" data/sw2.png --checkpoint \'naver-clova-ix/donut-base-finetuned-docvqa\'',
#   0.08555090427398682),
#  ('tmux -a', 0.08554956316947937),
#  ("NEW_DB_DOMAIN=`echo $NEW_DB | sed 's/^.*\\/\\/\\([^:]*\\):.*$/\\1/'`\\",
#   0.08554016798734665),
#  ('git status "service serves over https, but still not registering instances"',
#   0.08529645949602127),
#  ('git diff src/ws2/cluster-ingress.ts', 0.08495540171861649),
#  ('ls docs/docs', 0.08490347862243652),
#  ('open data/nerf/fox/', 0.0848737359046936),
#  ('mv dev/release.sh scripts', 0.08472628891468048),
#  ('git add src/generated/graphql.schema.json', 0.0847250297665596),
#  ('rsync -r --info=progress2 -W ml:~/ml-experiments/results ./ml-experiments',
#   0.08465953171253204),
#  ('find ../node_modules/expo/android/build.gradle | entr -s "clear && ./gradlew expo"',
#   0.0841485783457756),
#  ('rm .nvmrc', 0.08412101864814758),
#  ('cd ../miner', 0.08405332267284393),
#  ('echo ".cfg" >> .gitignore\\', 0.08376872539520264),
#  ('yarn start:dev', 0.08354873210191727),
#  ('kubectl config get rp-stage', 0.08345921337604523),
#  ('code ~/.zsh_history', 0.08299139887094498),
#  ('which pip', 0.08249405026435852),
#  ('./bin/cshell', 0.08204679936170578),
#  ('./bin/cyarn', 0.08194345235824585),
#  ('git diff origin/main', 0.08191999793052673),
#  ('yarn codegen', 0.08188022673130035),
#  ('git diff ios/', 0.08186077326536179),
#  ('git restore src/generated/graphql.ts', 0.08168213069438934),
#  ('git rebase origin/main', 0.08148914575576782),
#  ('git checkout -b better-error-reporting', 0.08137772977352142),
#  ('poetry run docquery scan "am I paying in dollars or points" data/sw2.png',
#   0.08135931193828583),
#  ('git checkout refine-map', 0.08135142922401428),
#  ('git checkout package.json src/', 0.08128013461828232),
#  ('git stash list -p | grep ipy', 0.08096922934055328),
#  ('z cal', 0.08090133219957352),
#  ('git grep', 0.08073614537715912),
#  ('ls /opt/homebrew/anaconda3/bin/', 0.08068963885307312),
#  ('git add fastlane/ package.json', 0.0805727019906044),
#  ('git checkout main ../../../package.json', 0.07987846434116364),
#  ('wormhole receive 3-vagabond-dwelling', 0.07972364872694016),
#  ('git diff ios', 0.07970891892910004),
#  ('ls src/* | grep "/"', 0.07958471775054932),
#  ('brew install anaconda', 0.0795261338353157),
#  ('config push', 0.07945361733436584),
#  ('git checkout ftue-triggers', 0.07943574339151382),
#  ('cd instant-ngp', 0.0789995864033699),
#  ('cd ../', 0.07898078113794327),
#  ('cd ..', 0.07896940410137177),
#  ('code /tmp/prod_dump.sql', 0.07869765162467957),
#  ('git show 9b21c080', 0.07852331548929214),
#  ('which asdf', 0.07847792655229568),
#  ('z world', 0.07834291458129883),
#  ('cd ../..', 0.07823191583156586),
#  ('ls dev', 0.07816695421934128),
#  ('cat ~/.config/rclone/rclone.conf', 0.07814600318670273),
#  ('mv 20220826_144003.mp4 v2.mp4', 0.07811994105577469),
#  ('git add db/migrations/Migration20220831013848.ts db/migrations/.snapshot-worldserver.json',
#   0.07805290818214417),
#  ('yarn refresh', 0.07764029502868652),
#  ('sh -c "which node"', 0.07759355008602142),
#  ('yarn up:stage -f', 0.07708714157342911),
#  ('git reset --hard origin/main', 0.07705250382423401),
#  ('git checkout map-loading', 0.07695075124502182),
#  ('adb reverse tcp:8081 tcp:8081 && ./gradlew app:installLocalDebug',
#   0.07694520801305771),
#  ('code upgrade.diff', 0.07686159014701843),
#  ('which aslkjf', 0.07681243121623993),
#  ('config commit -a "config updates"', 0.07680443674325943),
#  ('git checkout master', 0.07658607512712479),
#  ('yarn  add @babel/runtime', 0.07626832276582718),
#  ('wget https://raw.githubusercontent.com/react-native-community/rn-diff-purge/diffs/diffs/0.68.2..0.70.1.diff',
#   0.076236292719841),
#  ('which config', 0.07618051767349243),
#  ('asdf global ruby 3.1.2', 0.07600267231464386),
#  ('mkdir proj', 0.07588112354278564),
#  ('z real', 0.07571358978748322),
#  ('pulumi stack output analyticsDbUrl --show-secrets --stack reality-platforms/stage\\',
#   0.07561063021421432),
#  ('git statuss', 0.07549368590116501),
#  ('yarn up:prod -f', 0.07548810541629791),
#  ('brew install smartmontools\\', 0.07509243488311768),
#  ('rm asdf -', 0.07507669180631638),
#  ('rm -rf node_modules', 0.07489323616027832),
#  ('git commit -am "0.1.13"', 0.07451093941926956),
#  ('echo "node_modules" > .gitignore', 0.0743977501988411),
#  ('curl https://raw.githubusercontent.com/react-native-community/rn-diff-purge/diffs/diffs/0.68.2..0.70.1.diff',
#   0.07439134269952774),
#  ('./gradlew tasks', 0.07427400350570679),
#  ('poetry run docquery scan "what is the departure airport" data/sw2.png',
#   0.07419842481613159),
#  ('git commit -am "debug failing workflow"', 0.07419592142105103),
#  ('rm -rf /opt/homebrew/anaconda3/envs/ldm && conda env create -f environment-mac.yaml',
#   0.07410360872745514),
#  ('code .env', 0.07402929663658142),
#  ('open ios/RealityMiner.xcworkspace', 0.07362942397594452),
#  ('git restore --staged src/generated/', 0.07361587882041931),
#  ('find ../node_modules/expo/android/build.gradle | entr -s "./gradlew clean"',
#   0.07346870750188828),
#  ('cat /Users/kylecorbitt/.tool-versions', 0.07334046810865402),
#  ('git restore --staged', 0.07303321361541748),
#  ('gmend "end-of-sequence tweaks"', 0.07293670624494553),
#  ('z process', 0.07278639078140259),
#  ('config diff ../../../.gitconfig', 0.07276539504528046),
#  ('conda env create -f environment-mac.yaml', 0.07240612804889679),
#  ('poetry add docquery', 0.07139580696821213),
#  ('git stash list -S "ts"', 0.0713157057762146),
#  ('git diff src/ws', 0.07098230719566345),
#  ('git merge deploy-scanner', 0.07073299586772919),
#  ('config commit -m "config updates"', 0.07063668966293335),
#  ('cd /usr/local/bin', 0.0706019327044487),
#  ('gnb server-sentry', 0.0704449787735939),
#  ('pulumi state delete urn:pulumi:stage::infra::postgresql:index/extension:Extension::ws-postgis-stage',
#   0.07039452344179153),
#  ('git checkout origin/main -- src', 0.07020711898803711),
#  ('git checkout 502b57e0bdb1ff54eeb0f7c037016c6b1ff3b08d~',
#   0.07002543658018112),
#  ('rsync -r --info=progress2 --inplace ml:~/ml-experiments/results ./ml-experiments',
#   0.07000063359737396),
#  ('git diff', 0.06945742666721344),
#  ('code environment-mac.yaml', 0.06916049867868423),
#  ("alias config='/usr/bin/git --git-dir=$HOME/.cfg/ --work-tree=$HOME'\\",
#   0.06910765171051025),
#  ('./tunnel.sh', 0.06906059384346008),
#  ('psql postgres://worldserver:K30ELxNDfn8UCZ0U30F57rsKU50MET3A@ws2-stage.cluster-c5domkzijk75.us-west-2.rds.amazonaws.com:5432/worldserver',
#   0.06896139681339264),
#  ('cd scraping', 0.06895950436592102),
#  ('brew install magic-wormhole', 0.0688619613647461),
#  ('cd trial_remote2', 0.06877141445875168),
#  ('find ../node_modules/expo/android/build.gradle | entr -s "clear && ./gradlew clean"',
#   0.0685884952545166),
#  ('mkdur resume', 0.06830912828445435),
#  ('brew install protobuf', 0.06830253452062607),
#  ('ls trial_remote2', 0.06829681992530823),
#  ('code files.txt', 0.06828445941209793),
#  ('git checkout origin/main src', 0.06800783425569534),
#  ('cat outputs/stage/kubeconfig.yml', 0.0676623284816742),
#  ('find ../node_modules/expo/android/build.gradle', 0.06764916330575943),
#  ('cat pw.txt| pbcopy', 0.06754575669765472),
#  ('z down', 0.06746157258749008),
#  ('cd web', 0.06741242855787277),
#  ('ls -a src', 0.06729164719581604),
#  ('git diff src/ws2', 0.06729140877723694),
#  ('git add package.json', 0.06721314042806625),
#  ('mkdir nerf', 0.06682311743497849),
#  ('git checkout ftue', 0.06667480617761612),
#  ('ln -s docs /Users/kylecorbitt/odrive/amazon/kyle/Documents/',
#   0.066600501537323),
#  ('yarn up:prod', 0.06646551936864853),
#  ('yarn resumed init resume.json', 0.06611304730176926),
#  ('pulumi stack import --file /tmp/stack.json', 0.0659804567694664),
#  ('git add src/generated/graphql.ts', 0.06593097746372223),
#  ('git checkout explore-explorer', 0.06588777899742126),
#  ('git restore --source=HEAD --staged --worktree -- db/', 0.06587463617324829),
#  ('mv vncserver-service setup.sh xstartup templates', 0.06575106829404831),
#  ('cd run1', 0.06553399562835693),
#  ('gnb expo-workaround', 0.06547125428915024),
#  ('rsync -r --info=progress2 ml:~/ml-experiments .', 0.06540857255458832),
#  ('rm -r db && git restore --source=HEAD --staged --worktree -- db',
#   0.06535644084215164),
#  ('poetry run docquery scan "what is the departure airport" data/southwest.png',
#   0.06525778770446777),
#  ('rclone mount ml:ml-experiments .', 0.0651085302233696),
#  ('git branch -D recording-delay', 0.06505537778139114),
#  ('ls bin/redeploy.ts | entr "./bin/redeploy.ts stage"', 0.06505342572927475),
#  ('gnb explore-explorer', 0.06482022255659103),
#  ('rsync -r --info=progress2 -avuW --inplace ml:~/ml-experiments/results ./ml-experiments',
#   0.06479080021381378),
#  ('rm .env.production', 0.06478939950466156),
#  ('cat files.txt', 0.06469115614891052),
#  ('rsync -r --info=progress2 -W ml:~/ml-experiments .', 0.06467361003160477),
#  ('mv credentials ~/.aws/', 0.06453359872102737),
#  ('code ..', 0.06448213011026382),
#  ('git checkout smoother-map', 0.06430652737617493),
#  ('rm -rf dist/ node_modules/ temp/ && yarn install && ./bin/start-dev --build --renew-anon-volumes',
#   0.06430480629205704),
#  ('git diff src/blocks/', 0.06415755301713943),
#  ('pulumi stack output analyticsDbUrl --show-secrets', 0.06409772485494614),
#  ('git reset --hard 36c66ec862223872b8aaa6195cf1ca729cb726b8',
#   0.06387785822153091),
#  ('./provision.sh', 0.0637458860874176),
#  ('config checkout', 0.06373921781778336),
#  ('gnb ftue', 0.06369777023792267),
#  ('ls ml-experiments', 0.06323087960481644),
#  ('/usr/bin/env', 0.06310363113880157),
#  ('code git@github.com:NVlabs/instant-ngp.git', 0.06307943165302277),
#  ('cat asdf', 0.0630677118897438),
#  ('mv 20220826_143650.mp4 v1.mp4', 0.0628727525472641),
#  ('yarn up:stage', 0.06274449825286865),
#  ('./bin/cshell env', 0.0627218633890152),
#  ('config checkout ../../../.zshrc', 0.0626225546002388),
#  ('cd exp', 0.06241880729794502),
#  ('git diff .', 0.06232932209968567),
#  ('git checkout posthog-report', 0.062210481613874435),
#  ('code ../miner/env', 0.06207554414868355),
#  ('open metaverse-sample.mp4', 0.061808161437511444),
#  ('cat /Users/kylecorbitt/proj/reality-platforms/experiments/ml-machine/xstartup',
#   0.06174063682556152),
#  ('config pull', 0.06169089674949646),
#  ('rm android/app/src/main/jni/CMakeLists.txt', 0.06156177818775177),
#  ('z gradle', 0.0614517405629158),
#  ('env', 0.06129072606563568),
#  ('psql $(pulumi stack output analyticsDbUrl --show-secrets --stack reality-platforms/prod)',
#   0.06114239618182182),
#  ('psql postgres://worldserver:5WXFEeXYcFfoj94hwvu6I4mASGPkIEeY@ws2-prod.cluster-c5domkzijk75.us-west-2.rds.amazonaws.com:5432/worldserver',
#   0.06106443703174591),
#  ('node -p "require(\'./package.json\').version"', 0.060982707887887955),
#  ('git diff src/ws2/ws-api.ts', 0.06076844036579132),
#  ('Cannot instantiate this tokenizer from a slow version.',
#   0.06053149700164795),
#  ('scp ml:~/ml-experiments/data/apollo-rock/test-out.mp4 .',
#   0.06040715053677559),
#  ('config diff ../../../.ssh/config', 0.060075853019952774),
#  ('gnb posthog-report', 0.060016900300979614),
#  ('cd resume', 0.06000041216611862),
#  ('git reset --hard 288a93e5e10c9ba0feb99dee04169a752058a24e',
#   0.05995342880487442),
#  ('rm upgrade.diff', 0.05992025136947632),
#  ('git rebase --abort', 0.0599193274974823),
#  ('git add metaverse-sample.mp4', 0.059733279049396515),
#  ('z web', 0.059719547629356384),
#  ('cd', 0.05941329151391983),
#  ('brew update react-native-debugger', 0.05926911160349846),
#  ('git rebase include-lib', 0.059000641107559204),
#  ('cd Downloads', 0.05889306589961052),
#  ('brew upgrade visual-studio-code', 0.058861661702394485),
#  ('cat outputs/stage/kubeconfig2.yml', 0.058585524559020996),
#  ('gnb fix-build', 0.05854654684662819),
#  ('yarn remove i18n-iso-countries', 0.05853556841611862),
#  ('rsync -r --info=progress2 -W ml:~/ml-experiments/trial_remote2 ./ml-experiments/trial_remote2',
#   0.05833923816680908),
#  ('node -r', 0.058232374489307404),
#  ('gnb 0.1.6', 0.05815889313817024),
#  ('git checkout src', 0.05815248191356659),
#  ('which adb', 0.05799936503171921),
#  ('./bin/redeploy.ts prod', 0.05792273208498955),
#  ('ssh -L 59000:localhost:5901 ubuntu@147.189.192.255', 0.05789865180850029),
#  ('git commit -am "remove sort by expiration"', 0.05786580219864845),
#  ('scp old:~/.gradle/gradle.properties ~/.gradle', 0.05763542652130127),
#  ('mkdir data', 0.05756639689207077),
#  ('cat ~/.ssh/config', 0.0575392059981823),
#  ('cd process-capture', 0.05746429041028023),
#  ('curl 147.189.192.180:443', 0.05743516981601715),
#  ('rm -rf dist/ node_modules/\\', 0.057211995124816895),
#  ('./bin/ssh.ts', 0.05707667022943497),
#  ('asdf install nodejs 16.13.0', 0.05668605864048004),
#  ('git stash list -i', 0.05660780146718025),
#  ('git commit -m "Don\'t catch pointer events in night warning"',
#   0.05655403062701225),
#  ('rsync -r --info=progress2 --inplace --no-compress ml:~/ml-experiments/results ./ml-experiments',
#   0.05653456971049309),
#  ('./bin/start-dev', 0.05640402063727379),
#  ('git checkout bump-rn', 0.05632294714450836),
#  ('cd /Users/kylecorbitt/proj/reality-platforms/miner/node_modules/expo/android',
#   0.0559673048555851),
#  ('git checkout src/site.ts', 0.05574888736009598),
#  ('git-cleanup', 0.055590592324733734),
#  ('git add src/ws2/index.ts', 0.055570051074028015),
#  ('git commit -am "0.1.6"', 0.05554571375250816),
#  ('./ssh.ts', 0.05552934482693672),
#  ('pulumi refresh:stage', 0.055398933589458466),
#  ('git diff yarn.lock', 0.055099766701459885),
#  ('git merge origin/main', 0.0550396591424942),
#  ('git pull --rebase', 0.0545208714902401),
#  ('yarn react-native start --reset-cache', 0.054442375898361206),
#  ('ls bin/redeploy.ts | entr -s "./bin/redeploy.ts stage"',
#   0.05428902059793472),
#  ('node -v', 0.05426885560154915),
#  ('mv ws2/* .', 0.054148029536008835),
#  ('poetry run docquery scan "how many passengers" data/sw2.png',
#   0.054047055542469025),
#  ('which node', 0.053984057158231735),
#  ('git diff src/ws2/', 0.053948819637298584),
#  ('psql $(pulumi stack output analyticsDbUrl --show-secrets --stack reality-platforms/stage)',
#   0.053895123302936554),
#  ('yarn tunnel', 0.05374825373291969),
#  ('conda install -y pytorch torchvision torchaudio -c pytorch-nightly',
#   0.05370967090129852),
#  ('git apply upgrade.diff', 0.053612951189279556),
#  ('git checkout .', 0.05347083508968353),
#  ('yarn up:stage -y', 0.05335307493805885),
#  ('git clone https://github.com/nvlabs/instant-ngp', 0.05324710160493851),
#  ('asdf install', 0.05317733436822891),
#  ('git checkout recording-delay', 0.05315617844462395),
#  ('brew install tesseract\\', 0.05294525623321533),
#  ('pg_dump --clean --create $OLD_DB > /tmp/db_dump_stage.sql\\',
#   0.0527612566947937),
#  ('git reset --hard more-ftue', 0.052750278264284134),
#  ('git reset --hard 22593ddd0666fd30d4eefdf26819a5b0c89192e2',
#   0.052572526037693024),
#  ('rsync --version', 0.052534278482198715),
#  ('ssh ubuntu@147.189.192.180 -L 443:localhost:443', 0.05253114178776741),
#  ('git checkout main -- .', 0.052505236119031906),
#  ('git revert origin/main .', 0.05238547548651695),
#  ('reboot 0', 0.052294183522462845),
#  ('git branch -D refine-map', 0.052280671894550323),
#  ('kubectl get svc --kubeconfig outputs/stage/kubeconfig.yml',
#   0.05220508947968483),
#  ('git checkout src/', 0.052057672291994095),
#  ('pip install sqlalchemy', 0.05198371410369873),
#  ('cat upgrade.diff', 0.051753636449575424),
#  ('gnb 0.1.1', 0.05171012878417969),
#  ('git commit -a', 0.05168314278125763),
#  ('yarn add puppeteer', 0.05126878619194031),
#  ('gnb founder-explorer', 0.05098925903439522),
#  ('rm -r Pulumi.yaml node_modules/ yarn.lock package-lock.json tsconfig.json index.ts',
#   0.0508800633251667),
#  ('ls /Users/kylecorbitt/Library/Caches/pypoetry/virtualenvs',
#   0.050763823091983795),
#  ('gnb ftui-updates', 0.05057445913553238),
#  ('z /Users/kylecorbitt/proj/', 0.05047653615474701),
#  ('open outputs/txt2img-samples/', 0.050328146666288376),
#  ('git commit -m "api served on ssl, but not bare"', 0.05013420432806015),
#  ('poetry config virtualenvs.in-project true', 0.049997951835393906),
#  ('git checkout -b credits-required-preload', 0.04995423182845116),
#  ('OPENBLAS="$(brew --prefix openblas)" poetry add git+https://github.com/impira/docquery.git\\',
#   0.049907587468624115),
#  ('kubectl current-context', 0.04979074001312256),
#  ('cd podcasts', 0.04969209432601929),
#  ('cd Desktop', 0.0496366024017334),
#  ('meld', 0.04963585361838341),
#  ('git reset --hard 6892bb36297c4a892670b4f21119e1685e8db5f1',
#   0.04949915036559105),
#  ('code ~/.zshrc', 0.04944160580635071),
#  ('fastlane android beta --stacktrace', 0.04915532469749451),
#  ('git checkout main ../../../ios', 0.04896450415253639),
#  ('git checkout app-tos', 0.04874253645539284),
#  ('ls -a', 0.04863748326897621),
#  ('ssh ubuntu@147.189.192.180 -L 443:localhost:4443', 0.04859170690178871),
#  ('git status', 0.048537738621234894),
#  ('pulumi state delete urn:pulumi:stage::infra::postgresql:index/extension:Extension::ws-postgis-prod --stack reality-platforms/prod',
#   0.048517271876335144),
#  ('git diff src/screens/FTUE/FTUEModal.tsx', 0.048514705151319504),
#  ('git commit -am "don\'t try to advance the FTUE before the user exists"',
#   0.04816766828298569),
#  ('poetry add git+https://github.com/impira/docquery.git\\',
#   0.048106059432029724),
#  ('z Desk', 0.04797612875699997),
#  ('z desk', 0.04797612875699997),
#  ('git checkout ios-loading', 0.04796573147177696),
#  ('git stash list -p', 0.04783482477068901),
#  ('git diff src/screens/RealityMaps/MapView/MapView.tsx', 0.04763549566268921),
#  ('ssh ubuntu@147.189.192.180 -L 4443:localhost:443', 0.04731590300798416),
#  ('env -i node', 0.047311145812273026),
#  ('git commit -am "better copy and triggers on upgrade FTUEs"',
#   0.047164954245090485),
#  ('./dev/release.sh', 0.04691648855805397),
#  ('kubectl describe hpa', 0.0468561016023159),
#  ('config stash ../../../.ssh/config ../../../.tool-versions ../../../.zshrc',
#   0.04647700861096382),
#  ('git show recording-delay', 0.046423666179180145),
#  ("aws elb describe-load-balancer-policies --query 'PolicyDescriptions[].PolicyName'\\",
#   0.04617337882518768),
#  ("git apply -p1 --directory='miner' upgrade.diff", 0.046163007616996765),
#  ('git clone git@github.com:NVlabs/instant-ngp.git', 0.0459856353700161),
#  ('yarn resumed export exported-resume.json', 0.04595842957496643),
#  ('git commit -am "0.1.11"', 0.04585760831832886),
#  ('ls src/*', 0.04576890170574188),
#  ('npx install-expo-modules@latest', 0.045648206025362015),
#  ('poetry add git+https://github.com/impira/transformers@153d1361c7dcc91c7735cae73e1f594cfcab3e21\\',
#   0.04545418545603752),
#  ('git checkout staging-k8s', 0.045333847403526306),
#  ('yarn add --dev yargs', 0.04530443623661995),
#  ('sudo reboot 0', 0.0452885776758194),
#  ('cat /tmp/task-*', 0.04523990675806999),
#  ('which ruby', 0.04494435340166092),
#  ('ls -R src', 0.044858418405056),
#  ('git config push.default current --global', 0.044840287417173386),
#  ('config commit -u "config updates"', 0.04478178918361664),
#  ('gnb slower-video', 0.04450495168566704),
#  ('node -e', 0.044472746551036835),
#  ('git checkout main', 0.044238220900297165),
#  ('z ml', 0.04419926553964615),
#  ('wormhole ssh --help', 0.04399433732032776),
#  ('git commit -am "redirect http to https"', 0.043825745582580566),
#  ('git add src/ws2/database.ts', 0.043678101152181625),
#  ('git stash list', 0.04364514350891113),
#  ('adb reverse tcp:8001 tcp:8001', 0.04346087574958801),
#  ('cd ios', 0.04342898353934288),
#  ('git add src/ws2/cluster.ts', 0.043422505259513855),
#  ('git clone git@gitlab.com:corbt/scraping.git', 0.04329106956720352),
#  ('pg_dump --clean --create --no-owner $OLD_DB > /tmp/db_dump_stage2.sql\\',
#   0.043224748224020004),
#  ('git rebase --continue', 0.04299914464354515),
#  ('ln -s /Users/kylecorbitt/odrive/amazon/kyle/Documents docs',
#   0.04298509657382965),
#  ('pulumi refresh --stack=reality-platforms/prod', 0.04296056181192398),
#  ('diff', 0.042850423604249954),
#  ('git add ..', 0.04271462932229042),
#  ('cd reality-platforms', 0.04266168922185898),
#  ('cat .zshrc', 0.04251498356461525),
#  ('z home', 0.04245404154062271),
#  ('open trial_remote2', 0.04242192953824997),
#  ('brew upgrade react-native-debugger', 0.04224573075771332),
#  ('echo "ruby 2.7.6" > .tool-versions', 0.04222654178738594),
#  ('ls node_modules', 0.04205761104822159),
#  ('gnb map-loading', 0.041823096573352814),
#  ('cd templates', 0.04180446267127991),
#  ('/usr/bin/env node', 0.041748594492673874),
#  ('z worl', 0.04161285236477852),
#  ('./gradlew clean', 0.04147655516862869),
#  ('yarn up:prod -y', 0.041074320673942566),
#  ('wormhole ssh accept 7-repellent-buzzard', 0.04101436585187912),
#  ('git revert .', 0.040939487516880035),
#  ('cat Pulumi.prod.yaml', 0.04071957617998123),
#  ('gnb sort-options', 0.04067866876721382),
#  ('pulumi state delete urn:pulumi:prod::infra::postgresql:index/extension:Extension::ws-postgis-prod --stack reality-platforms/prod',
#   0.04065398871898651),
#  ('wormhole receive 1-supportive-dogsled', 0.04061145335435867),
#  ('asdf install nodejs 16.15', 0.0405689962208271),
#  ('brew install meld', 0.040461767464876175),
#  ('which ls', 0.04039313644170761),
#  ('scp old:~/proj/reality-platforms/miner/android/app/service-key.json .',
#   0.04038506746292114),
#  ('psql $OLD_DB', 0.04036921262741089),
#  ('pg_dump --clean --create $OLD_DB > /tmp/prod_dump.sql\\',
#   0.04024451971054077),
#  ('cat ~/.local/bin/poetry', 0.04006015509366989),
#  ('./android/gradlew tasks', 0.03987080603837967),
#  ('git cherry-pick 993bcd7d8fc60e8e3b20d35c2a2601f1a759f5e3',
#   0.039863329380750656),
#  ('git commit -am "more cleanup"', 0.03978154435753822),
#  ('gnb ios-simulator', 0.039646655321121216),
#  ('cd src/assets/videos', 0.039424777030944824),
#  ('yarn add @apollo/client@3.6.8', 0.039416179060935974),
#  ('gnb rename-app', 0.03939775004982948),
#  ('git add .', 0.039378851652145386),
#  ('code .', 0.03937277942895889),
#  ('poetry list', 0.039274610579013824),
#  ('brew install flipper', 0.03902334347367287),
#  ('cd tmp', 0.03893488645553589),
#  ('cd ml-machine', 0.038916051387786865),
#  ('asdf install rust latest', 0.03884298726916313),
#  ('man rg', 0.038706645369529724),
#  ('env -i node -v', 0.03860267996788025),
#  ('./bin/start-dev --env-file .env\\', 0.03838531672954559),
#  ('kubectl get-clusters', 0.038326360285282135),
#  ('asdf install nodejs 16.15.0', 0.03820481896400452),
#  ('mkdir resume', 0.03812902048230171),
#  ('git checkout unmined-neighborhood', 0.03792687505483627),
#  ('git commit -m "Fix broken typescript"', 0.03762621060013771),
#  ('git checkout more-ftue', 0.03746938705444336),
#  ('git commit -am "try to debug failing yarn install"', 0.037289634346961975),
#  ('cd .venv/bin', 0.036951594054698944),
#  ('git add ../infra/src/ws-api.ts', 0.036939024925231934),
#  ('git add ../world-server/', 0.03670814260840416),
#  ('sudo su', 0.03668387606739998),
#  ('yarn flow-copy-source', 0.036554694175720215),
#  ('gnb redeploy-count', 0.03651190549135208),
#  ('git add src/app.module.ts', 0.036471135914325714),
#  ('psql $NEW_DB', 0.03641503304243088),
#  ('brew install nixfmt', 0.03638126701116562),
#  ('git commit -m "v0.1.3"', 0.03636641800403595),
#  ('git cherry-pick 4d0bf5eb5a6a8ae0f538532b9f23dfeaf37bcf1b',
#   0.03633429482579231),
#  ('git checkout alpha-release', 0.03633030131459236),
#  ('pulumi stack select reality-platforms/prod', 0.036187805235385895),
#  ('git commit -m "final changes before cutover"', 0.03607434779405594),
#  ('cd ml', 0.03596222773194313),
#  ('git commit -m "clean up old ECS infra"', 0.035939112305641174),
#  ('z assets', 0.035739921033382416),
#  ('gnb process-blocks', 0.03561822324991226),
#  ('rclone config', 0.03549906611442566),
#  ('chmod a+x setup.sh', 0.03537268936634064),
#  ('z website', 0.03531312942504883),
#  ('kubectl get cm -n kube-system aws-auth -oyaml --kubeconfig outputs/stage/kubeconfig.yml',
#   0.03526461124420166),
#  ('git commit -m "More FTUE updates"', 0.03524099662899971),
#  ('./bin/start-dev\\', 0.03521082177758217),
#  ('asdf install ruby', 0.03473862260580063),
#  ('npm install', 0.0346175916492939),
#  ('ls -a src/*', 0.03458700329065323),
#  ('git cherry-pick 9b21c080', 0.03450177609920502),
#  ('node', 0.0344276949763298),
#  ('git commit -am "0.1.7"', 0.034418169409036636),
#  ('config add ~/.config/rclone/rclone.conf', 0.03425256907939911),
#  ('gnb building-ftue', 0.034226592630147934),
#  ('git drop stash@{4}', 0.03402329236268997),
#  ('cd ~/odrive', 0.03400041162967682),
#  ('z site', 0.03392472118139267),
#  ('git diff android/', 0.033920224756002426),
#  ('kubectl config get-clusters', 0.03381434082984924),
#  ('npx react-native-clean-project', 0.03379352390766144),
#  ('node -h', 0.03378872200846672),
#  ('docker manifest', 0.03365543484687805),
#  ('brew install realvnc', 0.03347928076982498),
#  ('z ssh', 0.033380135893821716),
#  ('git push -f', 0.03319130092859268),
#  ('asdf install plugin ruby', 0.03313756734132767),
#  ('ls -l /Users/kylecorbitt/odrive/kyle-rp/nerf/torch-ngp/scripts/install_colmap.sh',
#   0.032901227474212646),
#  ('code /opt/homebrew/anaconda3/envs/ldm/lib/python3.10/site-packages/torch/functional.py',
#   0.03289603069424629),
#  ('asdf plugin add ruby', 0.032822512090206146),
#  ('adb reverse tcp:8081 tcp:8081', 0.03267489746212959),
#  ('gnb game-server', 0.032596588134765625),
#  ('yarn add react-native-video@latest', 0.03251177817583084),
#  ('git commit -m "http->https redirect working"', 0.03247744217514992),
#  ('git diff ../world-server/process-capture/src/process_capture.py',
#   0.0320945605635643),
#  ('git branch -d ftue-ui', 0.03195367008447647),
#  ('git branch -D ftue-ui', 0.03195367008447647),
#  ('env -i "node -v"', 0.03193903714418411),
#  ('gnb and-where', 0.03192956745624542),
#  ('git commit -m "0.1.0"', 0.03176425024867058),
#  ('gnb fix-upgrades', 0.03167694807052612),
#  ('git reset --hard', 0.03159494325518608),
#  ('cd scripts', 0.03136610612273216),
#  ('ssh ubuntu@147.189.192.180', 0.031310129910707474),
#  ('git commit -m "release"', 0.03125343471765518),
#  ('kubectl set-cluster outputs/stage/kubeconfig.yml', 0.03118007630109787),
#  ('gnb block-details', 0.031177354976534843),
#  ('asdf install ruby 2.7.6', 0.031089458614587784),
#  ('git cherry-pick 06c90f67ad7674430c74ee76330c4cde8e027d54',
#   0.031066978350281715),
#  ('git add src/ws2/cluster-ingress.ts', 0.031054193153977394),
#  ('git commit -a --amend', 0.030961891636252403),
#  ('gnb terms-whenever', 0.030869020149111748),
#  ('sudo xcode-select --print-path', 0.030831877142190933),
#  ('gnb map-deadlock', 0.030788090080022812),
#  ('ls instant-ngp/', 0.03054584562778473),
#  ('asdf install ruby latest', 0.030500715598464012),
#  ('ls -l src/*', 0.03042854741215706),
#  ('psql postgres://analytics:BeUBjiSK006L0vAkXZOS5NKIT1U94pRj@ws2-prod.cluster-c5domkzijk75.us-west-2.rds.amazonaws.com:5432/worldserver',
#   0.030418813228607178),
#  ('git commit -m "include the compiled lib/"', 0.0303514301776886),
#  ('pulumi refresh --stack=reality-platforms/stage', 0.030296560376882553),
#  ("git apply -p2 --directory='miner' upgrade.diff", 0.030282828956842422),
#  ('git clone --bare git@gitlab.com:corbt/dotfiles.git $HOME/.cfg',
#   0.030215512961149216),
#  ('/opt/homebrew/anaconda3/bin/conda install bash', 0.030155159533023834),
#  ('kubectl get svc', 0.030103720724582672),
#  ('pulumi stack export > /tmp/stack.json', 0.029813479632139206),
#  ('code ~/.ssh/config', 0.02957727573812008),
#  ('cat Dockerfile', 0.029458895325660706),
#  ('git push', 0.02919306606054306),
#  ('docker build --build-arg NEXT_PUBLIC_API_URL=https://api.rpstage.org --target runner ../website',
#   0.028890566900372505),
#  ('./bin/redeploy.ts', 0.02875947766005993),
#  ('printf "$NEXT_PUBLIC_API_URL" >> .env.production', 0.028746547177433968),
#  ('pg_dump --clean --create --no-owner $OLD_DB > /tmp/prod_dump_latest.sql\\',
#   0.02863544411957264),
#  ('git checkout -b include-lib', 0.02857159450650215),
#  ('macfuse', 0.02849404700100422),
#  ('git checkout -', 0.028445888310670853),
#  ('git commit -m "0.1.1"', 0.02831920050084591),
#  ('yarn add rnmapbox/maps#main', 0.028311748057603836),
#  ('git checkout tweak-infra', 0.028285730630159378),
#  ('git checkout -b app-tos', 0.028214702382683754),
#  ('cd android', 0.027910863980650902),
#  ('git add ../miner/', 0.027750885114073753),
#  ('gnb release', 0.027341241016983986),
#  ('git checkout -b alpha-release', 0.027249880135059357),
#  ('git checkout apple-silicon-mps-support', 0.027143307030200958),
#  ('gnb skip-capture-quality', 0.026893597096204758),
#  ('fastlane', 0.026860643178224564),
#  ('yarn add suncalc', 0.026840612292289734),
#  ('git cherry-pick b4d30796057b84e8757b7989a66e0ebc00e43d34',
#   0.026625124737620354),
#  ('npx react-native init AwesomeProject\\', 0.02659587562084198),
#  ('git add src', 0.026582583785057068),
#  ('brew install amazon-drive', 0.026272162795066833),
#  ('gnb device-info', 0.026215633377432823),
#  ('chmod a+x provision.sh', 0.02619275078177452),
#  ('brew upgrade vs-code', 0.02615848183631897),
#  ('git cherry-pick 22593ddd0666fd30d4eefdf26819a5b0c89192e2',
#   0.026048030704259872),
#  ('brew reinstall openjds', 0.02597552351653576),
#  ('cd website', 0.025922391563653946),
#  ('brew install cmake', 0.02591729909181595),
#  ('git add src/utils/posthog.tsx', 0.02588828280568123),
#  ('git show stash@{4}', 0.025867508724331856),
#  ('git checkout db/migrations/', 0.025633040815591812),
#  ('./gradlew clean -p android', 0.02559278905391693),
#  ('pg_dump --clean --create --no-owner $OLD_DB > /tmp/prod_dump.sql\\',
#   0.025500385090708733),
#  ('cd src/assets', 0.025482531636953354),
#  ('rm -r ws2', 0.025480816140770912),
#  ('entr help', 0.025241602212190628),
#  ('scp ~/Desktop/video.mp4 ml:~/ml-experiments/data/porch-plant',
#   0.025050655007362366),
#  ('mv ../miner/src/assets/icons/why-reality-maps.png ../miner/src/assets/images',
#   0.02496703714132309),
#  ('pulumi stage:up', 0.024822494015097618),
#  ('asdf plugin add python', 0.02470126748085022),
#  ('z min', 0.024443410336971283),
#  ('git checkout posthog-events', 0.024328822270035744),
#  ('yarn start', 0.02432727813720703),
#  ('git checkout data-upload', 0.024266120046377182),
#  ("export NEXT_PUBLIC_API_URL='asdf'", 0.024200115352869034),
#  ('./bin/cyarn mikro-orm schema:fresh -r --seed\\', 0.024158988147974014),
#  ('git clone git@github.com:reality-platforms/reality-platforms.git',
#   0.023903880268335342),
#  ('git checkout ../website/src/pages/_app.tsx', 0.023810528218746185),
#  ('asdf plugin-add rust https://github.com/code-lever/asdf-rust.git\\',
#   0.02374885231256485),
#  ('./release.sh', 0.02372625656425953),
#  ('./bin/cyarn mikro-orm seeder:run', 0.023537520319223404),
#  ('git merge uragirii:conditional-render', 0.023205826058983803),
#  ('git checkout wallet-sort', 0.023174941539764404),
#  ('npm install --global yarn', 0.023093421012163162),
#  ('mkdir outputs/prod', 0.023010360077023506),
#  ('git checkout --mine src/screens/RealityMaps/MapView/MapLayers.tsx',
#   0.02293568104505539),
#  ('git commit -m "review tweaks"', 0.02287342958152294),
#  ('git checkout ../world-server/process-capture/src/process_capture.py',
#   0.02283455803990364),
#  ('git reset', 0.022775957360863686),
#  ('pulumi refresh -y --stack=reality-platforms/stage', 0.022762887179851532),
#  ('asdf plugin install ruby', 0.0227606613188982),
#  ('yarn install', 0.02270517125725746),
#  ('kubectl get cm -n kube-system aws-auth -oyaml --kubeconfig outputs/prod/kubeconfig.yml',
#   0.022484630346298218),
#  ('yarn install --frozen-lockfile', 0.022452671080827713),
#  ('scp ~/.gitconfig ml:~/.gitconfig', 0.022120311856269836),
#  ('mv docs southwest.png', 0.022030489519238472),
#  ('pip install pandas', 0.02194540947675705),
#  ('git pull', 0.021690480411052704),
#  ('git add src/navigation/BottomTabNavigator.tsx', 0.021606016904115677),
#  ('pulumi stack select reality-platforms/stage', 0.021533001214265823),
#  ('config add -u', 0.021356750279664993),
#  ('pwd', 0.02111878991127014),
#  ('scp old:~/proj/reality-platforms/miner/android/app/release-key.p12 .',
#   0.020888986065983772),
#  ('ls', 0.02076965570449829),
#  ('yarn ios --help', 0.020524809136986732),
#  ('kubectl config set-cluster stage', 0.02046990767121315),
#  ('gnb posthog-events', 0.020171426236629486),
#  ('ls data', 0.020044909790158272),
#  ('git log', 0.019795512780547142),
#  ('brew tap homebrew/cask-fonts', 0.019601257517933846),
#  ('brew install figma', 0.019499002024531364),
#  ('git checkout ios', 0.019449464976787567),
#  ('curl localhost:4443', 0.01936211995780468),
#  ('gnb cdn', 0.01931736245751381),
#  ('git clone git@gitlab.com:corbt/podcasts.git', 0.019130166620016098),
#  ('git merge uragirii/conditional-render', 0.018928421661257744),
#  ('z pod', 0.01865534484386444),
#  ('mv ~/Desktop/gradle-wrapper.jar android/gradle/wrapper/',
#   0.018411686643958092),
#  ('git checkout camera-quality', 0.018379608169198036),
#  ('adb devices', 0.018371598795056343),
#  ('kubectl set cluster outputs/stage/kubeconfig.yml', 0.017978327348828316),
#  ('yarn', 0.01795681193470955),
#  ('source "/Users/kylecorbitt/.asdf/installs/rust/1.63.0/env"',
#   0.017939401790499687),
#  ('pulumi state export', 0.017705246806144714),
#  ('pulumi stack output kubeconfig --stack reality-platforms/stage | kubectl config set-cluster rp-stage --kubeconfig=asdf',
#   0.017653122544288635),
#  ('mkdir models/ldm/stable-diffusion-v1', 0.017426971346139908),
#  ('mv ~/Downloads/mug.mp4 video.mp4', 0.017414381727576256),
#  ('pulumi export analyticsDbUrl', 0.017349418252706528),
#  ('cd ../tmp', 0.017192335799336433),
#  ('ls -l', 0.01714671403169632),
#  ('poetry add protobuf@3.18', 0.017124902456998825),
#  ('brew install macfuse', 0.016986405476927757),
#  ('ls ~/.ssh', 0.01668448932468891),
#  ('yarn resumed export', 0.0166252963244915),
#  ('rm outputs/stage/kubeconfig2.yml', 0.016572503373026848),
#  ('pulumi state', 0.01650349237024784),
#  ('git branch -D 0.1.1', 0.016400443390011787),
#  ('gnb unmined-neighborhood', 0.016201063990592957),
#  ('npm install yarn', 0.01599068194627762),
#  ("echo $NEW_DB | sed 's/^.*\\@\\([^:]*\\):.*$/\\1/'", 0.01593845523893833),
#  ('git commit -am "landing page served from k8s in stage"',
#   0.01591506227850914),
#  ('git merge uragirii -- conditional-render', 0.015736091881990433),
#  ('gnb more-ftue', 0.015627887099981308),
#  ('env -i sh', 0.015444310382008553),
#  ('curl localhost:59000', 0.015299852006137371),
#  ('gmend', 0.01527501456439495),
#  ('git checkout -b block-details', 0.015189377591013908),
#  ('pulumi export state', 0.01514142844825983),
#  ('poetry help list', 0.015140530653297901),
#  ('rm .ssh/config', 0.015080301091074944),
#  ("echo $NEW_DB | sed 's/^.*\\@([^:]*\\):.*$/\\1/'", 0.015050264075398445),
#  ('eiifccrchucfhrjrvvnrrgljiicijkhrkgfjbhjijhnr', 0.01504052896052599),
#  ('"', 0.014959543012082577),
#  ('git commit -am "fix sign-in and make reset more type-safe"',
#   0.014956232160329819),
#  ('git checkout --theirs src/screens/RealityMaps/MapView/MapLayers.tsx',
#   0.01442535500973463),
#  ('git stash show', 0.014409784227609634),
#  ('gnb staging-k8s', 0.014383443631231785),
#  ('yarn ios', 0.014350646175444126),
#  ('ssh old', 0.014325628988444805),
#  ('git checkout uragirii/conditional-render', 0.01429857686161995),
#  ('open ~/odrive', 0.014164787717163563),
#  ('gnb ios-loading', 0.014141201972961426),
#  ('ssh kyle@MacBook-Pro-57.local', 0.013986942358314991),
#  ('cd /Users/kylecorbitt/proj/reality-platforms/website/public/static/fonts/',
#   0.013949328102171421),
#  ('code ../.github', 0.013909361325204372),
#  ('git commit --amend', 0.013843207620084286),
#  ('gnb next-release', 0.013737577013671398),
#  ('ln -s node /Users/kylecorbitt/.asdf/shims/node', 0.01362861692905426),
#  ('ls -la', 0.013616230338811874),
#  ('git add src/', 0.013451392762362957),
#  ('asdf install python 3.10.6', 0.013318762183189392),
#  ('docker', 0.013280031271278858),
#  ('wormhole receive 5-ohio-rhythm', 0.012845156714320183),
#  ('kubectl get --raw /metrics\\', 0.012829354964196682),
#  ('which nodejs', 0.012762499041855335),
#  ('poetry config settings.virtualenvs.in-project true', 0.012234598398208618),
#  ('yarn add react-native-device-info@latest', 0.012220459058880806),
#  ('ssh ubuntu@147.189.192.255', 0.012167283333837986),
#  ('pulumi up:stage', 0.012120626866817474),
#  ('touch release.sh', 0.012096656486392021),
#  ('mv ml ml-machine', 0.012004227377474308),
#  ("echo $NEW_DB | sed 's/^.*\\@([^:]*):.*$/\\1/'", 0.011797214858233929),
#  ('brew install --cask postgres-unofficial', 0.011721957474946976),
#  ('pulumi new typescript', 0.011629773303866386),
#  ('asdf plugin add nodejs', 0.01158788613975048),
#  ('fastlane alpha', 0.011571666225790977),
#  ('yarn add react-native-posthog', 0.011490696109831333),
#  ('rm -r db && git restore --source=origin/main --staged --worktree -- db && ./bin/cyarn mikro-orm migration:create',
#   0.011312374845147133),
#  ('man entr', 0.011131245642900467),
#  ('scp install_colmap.sh ml:~', 0.010986450128257275),
#  ('git commit', 0.010889824479818344),
#  ('cd torch-ngp', 0.010853603482246399),
#  ('tail -f /tmp/task-*', 0.010583869181573391),
#  ('git diff ../website/Dockerfile', 0.01028148178011179),
#  ('mkdir templates', 0.010205982252955437),
#  ('echo \'eval "$(/opt/homebrew/bin/brew shellenv)"\' >> /Users/kylecorbitt/.zprofile',
#   0.010039379820227623),
#  ('gnb remove-founders', 0.00994829460978508),
#  ('rg -ii node_modules ViewProptypes', 0.009764024056494236),
#  ('ls /Users/kylecorbitt/odrive/amazon/kyle/Documents', 0.009716097265481949),
#  ('git rebase migration', 0.009640105068683624),
#  ('KUBERNETES_MASTER=outputs/stage/kubeconfig.yml yarn up:stage',
#   0.009592224843800068),
#  ('which python', 0.00941348634660244),
#  ('pulumi refresh', 0.009280230849981308),
#  ('yarn prepublish', 0.009279079735279083),
#  ('pulumi stack output kubeconfig --stack reality-platforms/prod > ./outputs/prod/kubeconfig.yml',
#   0.009163035079836845),
#  ('git checkout main -- outputs', 0.009077934548258781),
#  ('kubectl set-cluster', 0.008933240547776222),
#  ('export KUBECONFIG=outputs/stage/kubeconfig.yml', 0.008757930248975754),
#  ('code ~/.gitconfig', 0.008693794719874859),
#  ('yarn add jsonresume-theme-caffeine', 0.0085822194814682),
#  ('git commit -m "autoscale API"', 0.008495488204061985),
#  ('git branch -D uw-redirect', 0.008461163379251957),
#  ('git branch -d uw-redirect', 0.008461163379251957),
#  ("echo $NEW_DB | sed 's/^.*@([^:]*\\):.*$/\\1/'", 0.00824783369898796),
#  ('yarn react-native upgrade --verbose', 0.008188999257981777),
#  ('mkdir exp', 0.00817171111702919),
#  ('git stash pop stash@{1}', 0.007906122133135796),
#  ('scp install_colmap.sh ml', 0.007846475578844547),
#  ('ln -s /Users/kylecorbitt/.asdf/shims/node node', 0.007604822516441345),
#  ('pulumi stack output', 0.007596604060381651),
#  ('mkdir mug', 0.007578606717288494),
#  ('which python3', 0.007448113989084959),
#  ('git rm stash@{4}', 0.007250784896314144),
#  ('eval "$(/opt/homebrew/bin/brew shellenv)"\\', 0.007246752269566059),
#  ('git stash pop stash@{4}', 0.007181833032518625),
#  ('yarn ssh', 0.006922951899468899),
#  ('brew install oh-my-zsh', 0.006461873650550842),
#  ('mv /Users/kylecorbitt/Downloads/new_rooftop_cylindrical_exposure_comp_in_out.mp4 metaverse-sample.mp4',
#   0.006362167652696371),
#  ('brew install ripgrep', 0.00629408610984683),
#  ('git stash', 0.006188046187162399),
#  ...]

# %%
from sentence_transformers import SentenceTransformer, util
model = SentenceTransformer('all-MiniLM-L6-v2')

# Embed the history locally using the model
history_embeddings = model.encode(history, convert_to_tensor=True)

# %%
# Find the closest matches based on cosine similarity
def best_matches_local(command):
    command_embedding = model.encode([command], convert_to_tensor=True)
    cosine_scores = util.cos_sim(history_embeddings, command_embedding)

    scored_entries = list(zip(history, [float(s[0]) for s in cosine_scores]))
    scored_entries = sorted(scored_entries, key=lambda x: x[1], reverse=True)

    return scored_entries[0:10]


best_matches_local("test collections resolver")
# Out:
# [('open test/data/test-failed-collections', 0.5578877329826355),
#  ('./bin/ctest --watchAll --testPathPattern map.resolver', 0.5521202683448792),
#  ('./bin/ctest --watchAll --testPathPattern map.resolver.e2e',
#   0.5180152654647827),
#  ('./bin/ctest --watchAll --testPathPattern my-blocks.resolver',
#   0.5114029049873352),
#  ('./bin/ctest --watchAll --testPathPattern map-resolver.e2e',
#   0.5093897581100464),
#  ('cd test-failed-collections', 0.5004051327705383),
#  ('./bin/ctest --watchAll --testPathPattern /collection.entity',
#   0.499368816614151),
#  ('./bin/ctest --watchAll --testPathPattern upgrade-block.resolver',
#   0.48529064655303955),
#  ('git checkout -b test-failing-collections', 0.40675830841064453),
#  ('./bin/cyarn command test-failed-collections', 0.3983615040779114)]

# %%
# Just for fun let's try indexing with FAISS

import faiss
import numpy as np

# Index the history
index = faiss.IndexIDMap(faiss.IndexFlatIP(384))

display(model.encode(history).shape)

index.add_with_ids(model.encode(history), np.array(range(0, len(history_embeddings))))

def best_matches_faiss(command):
    command_embedding = model.encode([command])

    top_entries = index.search(command_embedding, 10)

    return [history[i] for i in top_entries[1][0]]

best_matches_faiss("test collections resolver")
# Out:
# (1368, 384)
# ['open test/data/test-failed-collections',
#  './bin/ctest --watchAll --testPathPattern map.resolver',
#  './bin/ctest --watchAll --testPathPattern map.resolver.e2e',
#  './bin/ctest --watchAll --testPathPattern my-blocks.resolver',
#  './bin/ctest --watchAll --testPathPattern map-resolver.e2e',
#  'cd test-failed-collections',
#  './bin/ctest --watchAll --testPathPattern /collection.entity',
#  './bin/ctest --watchAll --testPathPattern upgrade-block.resolver',
#  'git checkout -b test-failing-collections',
#  './bin/cyarn command test-failed-collections']

# %%
# Benchmark performance of best_matches_local vs best_matches_faiss

import time

def benchmark(command):
    start = time.time()
    best_matches_local(command)
    end = time.time()
    print(f"Local search took {end - start} seconds")

    start = time.time()
    best_matches_faiss(command)
    end = time.time()
    print(f"FAISS search took {end - start} seconds")

benchmark("git commit -m")
# Out:
# Top matches for command `git commit -m`:
# ['git commit',
#  'git commit -m "release"',
#  'git commit -a',
#  'git commit -m "0.1.1"',
#  'git commit -m "0.1.0"',
#  'git commit -m "correct provider"',
#  'git commit -m "v0.1.3"',
#  'git commit -m "final changes before cutover"',
#  'git commit -m "Check the ToS whenever"',
#  'git commit -am "more cleanup"']
# Local search took 0.016939163208007812 seconds
# FAISS search took 0.01026606559753418 seconds
